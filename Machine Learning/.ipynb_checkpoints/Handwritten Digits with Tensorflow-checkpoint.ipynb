# %% [markdown]
# # Reading Handwritten Digits with Tensorflow

# %% [markdown]
# What we're doing:
# https://www.tensorflow.org/tutorials/keras/classification

# %%
import tensorflow as tf
from keras.datasets import mnist
import keras
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# Out:
# 2024-05-08 13:13:57.863540: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-08 13:13:58.015315: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-08 13:13:58.015355: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-08 13:13:58.016191: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-08 13:13:58.086464: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-08 13:13:58.087293: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-08 13:13:59.542347: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
## Do I have GPUs?
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# ## Read in the data

# %% [markdown]
# X is the image, y is the label

# %%
(train_x,train_y), (test_x,test_y) = mnist.load_data()

# %%
type(train_x)
# Out:
# numpy.ndarray

# %% [markdown]
# ## What Does an Image look like?

# %%
print(train_x.shape, train_y.shape,test_x.shape,test_y.shape)
# Out:
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)

# %%
# Prepare the data for training

# %%
train_x = train_x / 255
test_x = test_x / 255

# %%
#print(train_x[0])
train_x[0].shape
# Out:
# (28, 28)

# %%
# graphit(the data to graph, the answers, # of rows of graph grid, # of cols of graph grid, where to start in the data, size of graph)
def graphit(images, labels, rows=1, cols=1, start=0, zoom=2):
   #The number of images we have to graph
  n_images = rows * cols
    #Make a graph the correct size
  fig, ax = plt.subplots(rows,cols,figsize=(cols * zoom, rows * zoom))
    # For every graph we need to make
  for n in range(n_images):
    plt.subplot(rows, cols, n+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[n+start], cmap=plt.cm.binary)
    # plt.imshow(images[n])
    plt.xlabel("[" + str(n+start) + "] is a : " + str(labels[n+start]))
  plt.show()

# %%
graphit(test_x,test_y,2,2,1,zoom=1.5)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(32,activation="relu"),
    tf.keras.layers.Dense(10,activation="softmax")
])

# %% [markdown]
# ## Compile the Model

# %%
model.compile(optimizer="adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=["accuracy"])

# %%
# model.fit(train_x,train_y,epochs=10)
train_y.size
# Out:
# 60000

# %%
history = model.fit(train_x,train_y,epochs=50,batch_size=1024)
# Out:
# Epoch 1/50
# 21/59 [=========>....................] - ETA: 0s - loss: 0.0325 - accuracy: 0.9886
# 2024-05-08 13:20:29.832584: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 188160000 exceeds 10% of free system memory.
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0325 - accuracy: 0.9896
# Epoch 2/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0310 - accuracy: 0.9895
# Epoch 3/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0306 - accuracy: 0.9899
# Epoch 4/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0301 - accuracy: 0.9904
# Epoch 5/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0278 - accuracy: 0.9913
# Epoch 6/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0283 - accuracy: 0.9913
# Epoch 7/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 0.9911
# Epoch 8/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0276 - accuracy: 0.9911
# Epoch 9/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9915
# Epoch 10/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 0.9927
# Epoch 11/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0251 - accuracy: 0.9924
# Epoch 12/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0243 - accuracy: 0.9920
# Epoch 13/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9925
# Epoch 14/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0226 - accuracy: 0.9927
# Epoch 15/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0240 - accuracy: 0.9918
# Epoch 16/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0225 - accuracy: 0.9925
# Epoch 17/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 0.9933
# Epoch 18/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 0.9936
# Epoch 19/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9932
# Epoch 20/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0208 - accuracy: 0.9929
# Epoch 21/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9935
# Epoch 22/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9938
# Epoch 23/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9935
# Epoch 24/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9936
# Epoch 25/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9935
# Epoch 26/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9938
# Epoch 27/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0182 - accuracy: 0.9938
# Epoch 28/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 0.9942
# Epoch 29/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0178 - accuracy: 0.9941
# Epoch 30/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9943
# Epoch 31/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9946
# Epoch 32/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0166 - accuracy: 0.9946
# Epoch 33/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9942
# Epoch 34/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9947
# Epoch 35/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 0.9944
# Epoch 36/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9941
# Epoch 37/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9949
# Epoch 38/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 0.9949
# Epoch 39/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9943
# Epoch 40/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 0.9950
# Epoch 41/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0153 - accuracy: 0.9951
# Epoch 42/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.9947
# Epoch 43/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9950
# Epoch 44/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.9944
# Epoch 45/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9949
# Epoch 46/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9952
# Epoch 47/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.9955
# Epoch 48/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9955
# Epoch 49/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9956
# Epoch 50/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9952

# %%
#list the number of epoch from the history object
x_values=np.arange(len(history.history["loss"]))

fig,ax1 = plt.subplots(figsize=(5,4))
fig.suptitle("Graph of Loss and Accuracy by Epochs",fontsize=20)
ax1.set_xlabel("Epochs")

ax1.set_ylabel("Loss",color="black",fontsize=14)
plot_1=ax1.plot(x_values,history.history["loss"],label="Loss")
ax1.tick_params(axis="y",labelcolor="black")

#adding twin axes

ax2 = ax1.twinx()
ax2.set_ylabel("Accuracy",color="red",fontsize=14)
plot_2=ax2.plot(x_values,history.history["accuracy"],label="Loss",color="red")
ax2.tick_params(axis="y",labelcolor="red")

plt.show()

# %%
test_loss,test_acc=model.evaluate(test_x,test_y,verbose=3)

print("\nTest accuracy:",test_acc*100,"%")
# Out:
# Test accuracy: 98.11999797821045 %

# %% [markdown]
# ## Predictions

# %% [markdown]
# #28x28 images

# %%
predictions = model.predict(test_x)
# Out:
# 313/313 [==============================] - 0s 831us/step

# %%
predictions[0]
# Out:
# array([2.1875808e-12, 1.6101140e-11, 1.9872196e-12, 1.3004641e-09,
#        7.9094952e-18, 1.8502156e-09, 4.6798279e-17, 9.9999994e-01,
#        1.9498033e-11, 1.3995247e-10], dtype=float32)

# %%
test_y[0]
# Out:
# 7

# %%
predictions[0].argmax()
# Out:
# 7

# %%
wrong = []
for i in range(len(predictions)):
    if predictions[i].argmax() != test_y[i]:
        wrong.append(i)

(10000-len(wrong))/10000
# Out:
# 0.9812

# %%
print(wrong)
# Out:
# [18, 217, 247, 321, 340, 445, 495, 582, 619, 684, 691, 720, 786, 810, 900, 938, 947, 951, 956, 1014, 1039, 1112, 1156, 1226, 1232, 1242, 1247, 1299, 1319, 1326, 1328, 1393, 1414, 1494, 1522, 1530, 1549, 1553, 1621, 1681, 1709, 1717, 1751, 1754, 1790, 1878, 1901, 1941, 1982, 2004, 2016, 2024, 2043, 2044, 2053, 2070, 2093, 2109, 2118, 2135, 2185, 2189, 2272, 2293, 2369, 2387, 2393, 2414, 2422, 2462, 2488, 2607, 2618, 2648, 2654, 2720, 2863, 2877, 2896, 2921, 2927, 2939, 2953, 3030, 3062, 3073, 3117, 3206, 3225, 3289, 3503, 3520, 3549, 3558, 3567, 3597, 3727, 3751, 3762, 3776, 3780, 3808, 3838, 3853, 3869, 3902, 3906, 3941, 3943, 3976, 4065, 4075, 4078, 4163, 4176, 4199, 4224, 4248, 4289, 4294, 4306, 4425, 4439, 4497, 4500, 4536, 4601, 4635, 4731, 4740, 4751, 4807, 4823, 4880, 4918, 4956, 5067, 5331, 5642, 5734, 5749, 5842, 5887, 5888, 5936, 5955, 5973, 6011, 6024, 6059, 6173, 6555, 6558, 6574, 6597, 6625, 6651, 6755, 6783, 7216, 7259, 7434, 7451, 7921, 8020, 8094, 8325, 8456, 8527, 9009, 9015, 9016, 9019, 9024, 9422, 9587, 9634, 9664, 9679, 9700, 9729, 9745, 9768, 9770, 9782, 9792, 9793, 9839]

# %%
n=8
predict=[]
predict.append(predictions[n].argmax())
imgs = []
imgs.append(test_x[n])
graphit(imgs,predict,1,1,0,zoom=4)

# %%
# Build data to graph the wrong ones

# %%
imgs,labels,predicts=[],[],[]
for i in range(25):
    imgs.append(test_x[wrong[i]])
    labels.append(test_y[wrong[i]])
    predicts.append(predictions[i].argmax())


#predict.append(predictions[n].argmax())
#imgs = []
#imgs.append(test_x[n])

# %%
# graphit(the data to graph, the answers, # of rows of graph grid, # of cols of graph grid, where to start in the data, size of graph)
def graph_predictions(images, labels, predictions, rows=1, cols=1, start=0, zoom=2):
   #The number of images we have to graph
  n_images = rows * cols
    #Make a graph the correct size
  fig, ax = plt.subplots(rows,cols,figsize=(cols * zoom, rows * zoom))
    # For every graph we need to make
  for n in range(n_images):
    plt.subplot(rows, cols, n+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[n+start], cmap=plt.cm.binary)
    # plt.imshow(images[n])
    plt.xlabel("[" + str(n+start) + "] is a : " + str(labels[n+start]) + " looks like : " + str(predictions[n+start]))
  plt.show()

# %%
graph_predictions(imgs,labels,predicts,5,5,0,zoom=3)
